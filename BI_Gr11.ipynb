# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from google.colab import drive
from tqdm import tqdm
import time
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path='/content/drive/MyDrive/Colab Notebooks/Store_Data/StoreDataCleaned.csv'
data=pd.read_csv(path)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  2011-01-01  2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  2011-01-01  2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220  2011-01-01  2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632  2011-01-01  2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-79397  2011-01-01  2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country          market   region  ...  \
# 0     Consumer      Constantine    Algeria          Africa   Africa  ...
# ...

# %%
data.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'product_name.1',
#        'product_name.2', 'product_name.3', 'product_name.4', 'product_name.5',
#        'Unit Price', 'quantity', 'discount', 'shipping_cost', 'order_priority',
#        'sales', 'expenses', 'revenue', 'year'],
#       dtype='object')

# %%
customers=data['customer_name'].unique().tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
transactions = []

for customer in tqdm(customers, desc="Processing customers", unit="customer"):
    ordeDF = data[(data['customer_name'] == customer) & ((data['year']==2014)| (data['year']==2013))]
    items = ordeDF['product_name'].unique().tolist()
    transactions.append(items)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Processing customers: 100%|██████████| 795/795 [00:07<00:00, 105.73customer/s]

# %%
len(transactions)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 795

# %%
# Convert transactions to a one-hot encoded DataFrame
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (795, 2183)

# %%
# !pip install efficient_apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
from scipy.sparse import csr_matrix
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Convert the transaction data to a sparse matrix
sparse_df = csr_matrix(df.values)

# Convert the sparse matrix to a DataFrame
dense_df = pd.DataFrame.sparse.from_spmatrix(sparse_df, columns=df.columns)

# Run Apriori algorithm
frequent_itemsets = apriori(dense_df, min_support=0.01, use_colnames=True)

# Filter out less interesting rules early to reduce memory usage
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# Display the frequent itemsets and rules
print("\nFrequent Itemsets:")
print(frequent_itemsets)

print("\nAssociation Rules:")
print(rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Frequent Itemsets:
#        support                                           itemsets
# 0     0.116981                                (Acco 3-Hole Punch)
# 1     0.122013                                      (Acco Binder)
# 2     0.118239                               (Acco Binder Covers)
# 3     0.106918                             (Acco Binding Machine)
# 4     0.110692                         (Acco Hole Reinforcements)
# ...        ...                                                ...
# 8445  0.011321  (Wilson Jones Index Tab, Wilson Jones Hole Rei...
# 8446  0.011321  (Wilson Jones Hole Reinforcements, Xerox Messa...
# ...

# %%
rules.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        antecedent support  consequent support   support  confidence      lift  \
# count            5.000000            5.000000  5.000000    5.000000  5.000000
# mean             0.018868            0.130818  0.010566    0.568959  4.339789
# std              0.003207            0.006890  0.000689    0.069445  0.348413
# min              0.015094            0.123270  0.010063    0.500000  4.056122
# 25%              0.016352            0.129560  0.010063    0.529412  4.086236
# 50%              0.018868            0.129560  0.010063    0.533333  4.116505
# ...

# %%
rules.head(100)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                        antecedents  \
# 0                 (Avery Binder, BIC Highlighters)
# 1               (Stockwell Push Pins, BIC Markers)
# 2  (Wilson Jones Hole Reinforcements, BIC Markers)
# 3             (Rogers File Cart, Stockwell Clamps)
# 4     (Cardinal Binding Machine, Stockwell Clamps)
#
#                           consequents  antecedent support  consequent support  \
# 0               (Stockwell Push Pins)            0.016352            0.129560
# 1  (Wilson Jones Hole Reinforcements)            0.015094            0.142138
# ...

# %%
object_columns = ['antecedents', 'consequents']
rules_cp = rules.copy()

# Convert object columns to string
# rules_cp[object_columns] = rules_cp[object_columns].applymap(str)

# Display the info of the new DataFrame
print(rules_cp.info())

rules_cp.head()

rules_cp['antecedents'] = rules_cp['antecedents'].apply(lambda x: ', '.join(list(x))).astype("unicode")
rules_cp['consequents'] = rules_cp['consequents'].apply(lambda x: ', '.join(list(x))).astype("unicode")

rules_cp.head(3)

rules_cp['antecedent_support'] = rules_cp['antecedent support']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   antecedents         5 non-null      object
#  1   consequents         5 non-null      object
#  2   antecedent support  5 non-null      float64
#  3   consequent support  5 non-null      float64
#  4   support             5 non-null      float64
#  5   confidence          5 non-null      float64
#  6   lift                5 non-null      float64
#  7   leverage            5 non-null      float64
# ...
